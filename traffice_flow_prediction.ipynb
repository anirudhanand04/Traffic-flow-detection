# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: DataSet/Readme.txt
#   inflating: DataSet/train13519.csv
#   inflating: DataSet/train13619.csv
#   inflating: DataSet/train13720.csv
#   inflating: DataSet/train13820.csv
#   inflating: DataSet/train13919.csv
#   inflating: DataSet/train14019.csv
#   inflating: DataSet/train14119.csv
#   inflating: DataSet/train14120.csv
#   inflating: DataSet/train14219.csv
#   inflating: DataSet/train14420.csv
#   inflating: DataSet/train14519.csv
#   inflating: DataSet/train14619.csv
#   inflating: DataSet/train14719.csv
#   inflating: DataSet/train14720.csv
#   inflating: DataSet/train14819.csv
#   inflating: DataSet/train14820.csv
#   inflating: DataSet/train14919.csv
#   inflating: DataSet/train14920.csv
#   inflating: DataSet/train15120.csv
#   inflating: DataSet/train16019.csv
#   inflating: DataSet/train16020.csv
#   inflating: DataSet/train20501.csv
#   inflating: DataSet/train20803.csv
#   inflating: DataSet/train24902.csv
#   inflating: DataSet/train24903.csv
#   inflating: DataSet/train24904.csv
#   inflating: DataSet/train25819.csv
#   inflating: DataSet/train25820.csv
#   inflating: DataSet/train25901.csv
#   inflating: DataSet/train25902.csv
#   inflating: DataSet/train26717.csv
#   inflating: DataSet/train26718.csv
#   inflating: DataSet/train26803.csv
#   inflating: DataSet/train26804.csv
#   inflating: DataSet/train27303.csv
#   inflating: dataset/DataSet/Readme.txt
#   inflating: dataset/DataSet/train13519.csv
#   inflating: dataset/DataSet/train13619.csv
#   inflating: dataset/DataSet/train13720.csv
#   inflating: dataset/DataSet/train13820.csv
#   inflating: dataset/DataSet/train13919.csv
#   inflating: dataset/DataSet/train14019.csv
#   inflating: dataset/DataSet/train14119.csv
#   inflating: dataset/DataSet/train14120.csv
#   inflating: dataset/DataSet/train14219.csv
#   inflating: dataset/DataSet/train14420.csv
#   inflating: dataset/DataSet/train14519.csv
#   inflating: dataset/DataSet/train14619.csv
#   inflating: dataset/DataSet/train14719.csv
#   inflating: dataset/DataSet/train14720.csv
#   inflating: dataset/DataSet/train14819.csv
#   inflating: dataset/DataSet/train14820.csv
#   inflating: dataset/DataSet/train14919.csv
#   inflating: dataset/DataSet/train14920.csv
#   inflating: dataset/DataSet/train15120.csv
#   inflating: dataset/DataSet/train16019.csv
#   inflating: dataset/DataSet/train16020.csv
#   inflating: dataset/DataSet/train20501.csv
#   inflating: dataset/DataSet/train20803.csv
#   inflating: dataset/DataSet/train24902.csv
#   inflating: dataset/DataSet/train24903.csv
#   inflating: dataset/DataSet/train24904.csv
#   inflating: dataset/DataSet/train25819.csv
#   inflating: dataset/DataSet/train25820.csv
#   inflating: dataset/DataSet/train25901.csv
#   inflating: dataset/DataSet/train25902.csv
#   inflating: dataset/DataSet/train26717.csv
#   inflating: dataset/DataSet/train26718.csv
#   inflating: dataset/DataSet/train26803.csv
#   inflating: dataset/DataSet/train26804.csv
#   inflating: dataset/DataSet/train27303.csv

# %% [markdown]
# ### Merging all CSV files into one

# %%
import pandas as pd
import glob

path = '/content/DataSet'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
print(df.head(3))
# Out:
#              timestamp  hourly_traffic_count
# 0  2015-10-04 00:00:00                    12
# 1  2015-10-04 00:05:00                     4
# 2  2015-10-04 00:10:00                     1

# %% [markdown]
# ### Descriptive Analysis

# %%
df.describe()
# Out:
#        hourly_traffic_count
# count         927360.000000
# mean              31.130331
# std               61.257467
# min                0.000000
# 25%                0.000000
# 50%                2.000000
# 75%               36.000000
# max              603.000000

# %% [markdown]
# ### Getting new features

# %%
df['timestamp'] = df['timestamp'].astype('datetime64[ns]')
df['weekday'] = df['timestamp'].dt.weekday

# Feature engineering with the date
df['year']= df['timestamp'].dt.year 
df['month']= df['timestamp'].dt.month 
df['day']= df['timestamp'].dt.day

df.head(3)

original_df = df.copy()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(50, 8))
mean_group = df[['timestamp','hourly_traffic_count']].groupby(['timestamp'])['hourly_traffic_count'].mean()
plt.plot(mean_group)
plt.title('Time Series - Average')
plt.show()

# %%
plt.figure(figsize=(50, 8))
median_group = df[['timestamp','hourly_traffic_count']].groupby(['timestamp'])['hourly_traffic_count'].median()
plt.plot(median_group, color = 'b')
plt.title('Time Series - median')
plt.show()

# %%
df['weekday_num'] = df['weekday']
df['weekday'].replace(0,'01 - Monday',inplace=True)
df['weekday'].replace(1,'02 - Tuesday',inplace=True)
df['weekday'].replace(2,'03 - Wednesday',inplace=True)
df['weekday'].replace(3,'04 - Thursday',inplace=True)
df['weekday'].replace(4,'05 - Friday',inplace=True)
df['weekday'].replace(5,'06 - Saturday',inplace=True)
df['weekday'].replace(6,'07 - Sunday',inplace=True)

train_group = df.groupby(["month", "weekday"])['hourly_traffic_count'].mean().reset_index()
train_group = train_group.pivot('weekday','month','hourly_traffic_count')
train_group.sort_index(inplace=True)

import seaborn as sns
sns.set(font_scale=1.2) 

f, ax = plt.subplots(figsize=(8, 8))
sns.heatmap(train_group, annot=False, ax=ax, fmt="d", linewidths=2)
plt.title('Web Traffic Months cross Weekdays')
plt.show()

# %% [markdown]
# ##### We can clearly see that there is no activity during the December and people during Octobor contributed the highest activity

# %%
times_series_means =  pd.DataFrame(mean_group).reset_index(drop=False)
times_series_means['weekday'] = times_series_means['timestamp'].apply(lambda x: x.weekday())
times_series_means['Date_str'] = times_series_means['timestamp'].apply(lambda x: str(x))
times_series_means[['year','month','day']] = pd.DataFrame(times_series_means['Date_str'].str.split('-',2).tolist(), columns = ['year','month','day'])
date_staging = pd.DataFrame(times_series_means['day'].str.split(' ',2).tolist(), columns = ['day','other'])
times_series_means['day'] = date_staging['day']*1
times_series_means.drop('Date_str',axis = 1, inplace =True)
del times_series_means['timestamp']
times_series_means.head()
# Out:
#    hourly_traffic_count  weekday  year month day
# 0             14.514286        6  2015    10  04
# 1             15.314286        6  2015    10  04
# 2             15.200000        6  2015    10  04
# 3             12.885714        6  2015    10  04
# 4             12.885714        6  2015    10  04

# %% [markdown]
# #### Train/Test Preparation

# %%
from sklearn.model_selection import train_test_split

X, y = times_series_means.drop(['hourly_traffic_count','year'],axis=1), times_series_means['hourly_traffic_count']
trainx, testx, trainy, testy = train_test_split(X, y, test_size=0.2)


# Linear Model
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from sklearn.metrics import mean_absolute_error, r2_score

def modelisation(x_tr, y_tr, x_ts, y_ts, model):
    # Modelisation with all product
    model.fit(x_tr, y_tr)

    prediction = model.predict(x_ts)
    r2 = r2_score(y_ts.to_numpy(), model.predict(x_ts))
    mae = mean_absolute_error(y_ts.to_numpy(), model.predict(x_ts))
    print ("-----------------------------------------------")
    print ("mae with 80% of the data to train:", mae)
    print ("-----------------------------------------------")
    
    return  prediction, model

model =  AdaBoostRegressor(n_estimators = 5000, random_state = 42, learning_rate=0.01)

prediction, clr = modelisation(trainx, trainy, testx, testy, model)
# Out:
# -----------------------------------------------
# mae with 80% of the data to train: 17.139391034145376
# -----------------------------------------------

# %%
import numpy as np
plt.figure(figsize=(16, 4))
line_up, = plt.plot(prediction,label='Prediction', color="red")
plt.ylabel('Series')
plt.legend(handles=[line_up])
plt.title('Performance of predictions - Benchmark Predictions')
plt.show()

# %%
plt.figure(figsize=(16, 6))
line_down, = plt.plot(np.array(testy),label='Reality')
plt.ylabel('Series')
plt.legend(handles=[line_down])
plt.title('Performance of predictions - Benchmark Reality')
plt.show()

# %%
trainx.shape
# Out:
# (21196, 3)

# %% [markdown]
# ### Keras LSTM

# %%
trainx.head()
# Out:
#        weekday month day
# 14909        1    11  24
# 933          2    10  07
# 20764        1    12  15
# 8901         1    11  03
# 13306        3    11  19

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from pandas import DataFrame, concat
from sklearn.preprocessing import MinMaxScaler


X, y = times_series_means.drop(['hourly_traffic_count','year'],axis=1), times_series_means['hourly_traffic_count']
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(X)

trainx, testx, trainy, testy = train_test_split(scaled, y, test_size=0.2)


trainx = trainx.reshape((trainx.shape[0], 1, trainx.shape[1]))
testx = testx.reshape((testx.shape[0], 1, testx.shape[1]))
 
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(trainx.shape[1], trainx.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(trainx, trainy, epochs=50, batch_size=8, validation_data=(testx, testy), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 2650/2650 - 16s - loss: 27.9954 - val_loss: 27.4411 - 16s/epoch - 6ms/step
# Epoch 2/50
# 2650/2650 - 9s - loss: 27.4582 - val_loss: 27.2540 - 9s/epoch - 3ms/step
# Epoch 3/50
# 2650/2650 - 9s - loss: 27.1721 - val_loss: 26.8389 - 9s/epoch - 3ms/step
# Epoch 4/50
# 2650/2650 - 9s - loss: 26.6581 - val_loss: 26.2426 - 9s/epoch - 3ms/step
# Epoch 5/50
# 2650/2650 - 8s - loss: 26.1066 - val_loss: 25.6678 - 8s/epoch - 3ms/step
# Epoch 6/50
# 2650/2650 - 8s - loss: 25.6740 - val_loss: 25.2137 - 8s/epoch - 3ms/step
# Epoch 7/50
# 2650/2650 - 9s - loss: 25.3007 - val_loss: 24.7986 - 9s/epoch - 3ms/step
# Epoch 8/50
# 2650/2650 - 8s - loss: 24.7814 - val_loss: 24.1305 - 8s/epoch - 3ms/step
# Epoch 9/50
# 2650/2650 - 8s - loss: 24.0651 - val_loss: 23.3444 - 8s/epoch - 3ms/step
# Epoch 10/50
# 2650/2650 - 8s - loss: 23.3326 - val_loss: 22.6501 - 8s/epoch - 3ms/step
# Epoch 11/50
# 2650/2650 - 9s - loss: 22.6996 - val_loss: 22.1099 - 9s/epoch - 3ms/step
# Epoch 12/50
# 2650/2650 - 10s - loss: 22.2287 - val_loss: 21.6775 - 10s/epoch - 4ms/step
# Epoch 13/50
# 2650/2650 - 9s - loss: 21.9459 - val_loss: 21.4734 - 9s/epoch - 3ms/step
# Epoch 14/50
# 2650/2650 - 9s - loss: 21.8045 - val_loss: 21.3953 - 9s/epoch - 3ms/step
# Epoch 15/50
# 2650/2650 - 9s - loss: 21.7319 - val_loss: 21.3414 - 9s/epoch - 3ms/step
# Epoch 16/50
# 2650/2650 - 9s - loss: 21.6748 - val_loss: 21.2907 - 9s/epoch - 3ms/step
# Epoch 17/50
# 2650/2650 - 8s - loss: 21.6168 - val_loss: 21.2340 - 8s/epoch - 3ms/step
# Epoch 18/50
# 2650/2650 - 9s - loss: 21.5566 - val_loss: 21.1820 - 9s/epoch - 3ms/step
# Epoch 19/50
# 2650/2650 - 8s - loss: 21.4919 - val_loss: 21.1239 - 8s/epoch - 3ms/step
# Epoch 20/50
# 2650/2650 - 9s - loss: 21.4251 - val_loss: 21.0520 - 9s/epoch - 3ms/step
# Epoch 21/50
# 2650/2650 - 9s - loss: 21.3668 - val_loss: 21.0583 - 9s/epoch - 3ms/step
# Epoch 22/50
# 2650/2650 - 9s - loss: 21.3136 - val_loss: 20.9567 - 9s/epoch - 3ms/step
# Epoch 23/50
# 2650/2650 - 9s - loss: 21.2727 - val_loss: 20.9350 - 9s/epoch - 3ms/step
# Epoch 24/50
# 2650/2650 - 8s - loss: 21.2433 - val_loss: 20.8955 - 8s/epoch - 3ms/step
# Epoch 25/50
# 2650/2650 - 9s - loss: 21.2127 - val_loss: 20.8649 - 9s/epoch - 3ms/step
# Epoch 26/50
# 2650/2650 - 9s - loss: 21.1846 - val_loss: 20.8367 - 9s/epoch - 3ms/step
# Epoch 27/50
# 2650/2650 - 9s - loss: 21.1615 - val_loss: 20.8123 - 9s/epoch - 3ms/step
# Epoch 28/50
# 2650/2650 - 9s - loss: 21.1394 - val_loss: 20.8179 - 9s/epoch - 3ms/step
# Epoch 29/50
# 2650/2650 - 9s - loss: 21.1158 - val_loss: 20.7741 - 9s/epoch - 3ms/step
# Epoch 30/50
# 2650/2650 - 9s - loss: 21.0937 - val_loss: 20.8051 - 9s/epoch - 3ms/step
# Epoch 31/50
# 2650/2650 - 8s - loss: 21.0703 - val_loss: 20.7526 - 8s/epoch - 3ms/step
# Epoch 32/50
# 2650/2650 - 9s - loss: 21.0527 - val_loss: 20.7441 - 9s/epoch - 3ms/step
# Epoch 33/50
# 2650/2650 - 9s - loss: 21.0316 - val_loss: 20.7633 - 9s/epoch - 3ms/step
# Epoch 34/50
# 2650/2650 - 9s - loss: 21.0143 - val_loss: 20.7106 - 9s/epoch - 3ms/step
# Epoch 35/50
# 2650/2650 - 9s - loss: 21.0008 - val_loss: 20.6655 - 9s/epoch - 3ms/step
# Epoch 36/50
# 2650/2650 - 9s - loss: 20.9814 - val_loss: 20.6692 - 9s/epoch - 3ms/step
# Epoch 37/50
# 2650/2650 - 8s - loss: 20.9661 - val_loss: 20.6921 - 8s/epoch - 3ms/step
# Epoch 38/50
# 2650/2650 - 9s - loss: 20.9499 - val_loss: 20.6308 - 9s/epoch - 3ms/step
# Epoch 39/50
# 2650/2650 - 10s - loss: 20.9380 - val_loss: 20.6235 - 10s/epoch - 4ms/step
# Epoch 40/50
# 2650/2650 - 9s - loss: 20.9226 - val_loss: 20.6109 - 9s/epoch - 3ms/step
# Epoch 41/50
# 2650/2650 - 8s - loss: 20.9121 - val_loss: 20.5987 - 8s/epoch - 3ms/step
# Epoch 42/50
# 2650/2650 - 9s - loss: 20.8936 - val_loss: 20.5881 - 9s/epoch - 3ms/step
# Epoch 43/50
# 2650/2650 - 8s - loss: 20.8871 - val_loss: 20.5822 - 8s/epoch - 3ms/step
# Epoch 44/50
# 2650/2650 - 8s - loss: 20.8757 - val_loss: 20.5853 - 8s/epoch - 3ms/step
# Epoch 45/50
# 2650/2650 - 9s - loss: 20.8715 - val_loss: 20.5607 - 9s/epoch - 4ms/step
# Epoch 46/50
# 2650/2650 - 9s - loss: 20.8598 - val_loss: 20.5636 - 9s/epoch - 3ms/step
# Epoch 47/50
# 2650/2650 - 9s - loss: 20.8534 - val_loss: 20.5523 - 9s/epoch - 3ms/step
# Epoch 48/50
# 2650/2650 - 8s - loss: 20.8438 - val_loss: 20.5410 - 8s/epoch - 3ms/step
# Epoch 49/50
# 2650/2650 - 8s - loss: 20.8373 - val_loss: 20.5408 - 8s/epoch - 3ms/step
# Epoch 50/50
# 2650/2650 - 9s - loss: 20.8311 - val_loss: 20.5352 - 9s/epoch - 4ms/step

# %% [markdown]
# #### Plot history and Evaluation

# %%
from sklearn.metrics import mean_squared_error

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
 
# make a prediction
yhat = model.predict(testx)
# calculate RMSE
rmse = np.sqrt(mean_squared_error(testy, yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# 166/166 [==============================] - 1s 2ms/step
# Test RMSE: 27.052
